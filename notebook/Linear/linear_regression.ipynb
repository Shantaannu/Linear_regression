# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install numpy
# !pip install statsmodels seaborn
# Out:
# Requirement already satisfied: pandas in e:\data mining & analysis\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in e:\data mining & analysis\.venv\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\data mining & analysis\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\data mining & analysis\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\data mining & analysis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in e:\data mining & analysis\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\data mining & analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in e:\data mining & analysis\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\data mining & analysis\.venv\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in e:\data mining & analysis\.venv\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\data mining & analysis\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\data mining & analysis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\data mining & analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in e:\data mining & analysis\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in e:\data mining & analysis\.venv\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in e:\data mining & analysis\.venv\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in e:\data mining & analysis\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in e:\data mining & analysis\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in e:\data mining & analysis\.venv\lib\site-packages (2.4.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: statsmodels in e:\data mining & analysis\.venv\lib\site-packages (0.14.6)
# Requirement already satisfied: seaborn in e:\data mining & analysis\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy<3,>=1.22.3 in e:\data mining & analysis\.venv\lib\site-packages (from statsmodels) (2.4.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\data mining & analysis\.venv\lib\site-packages (from statsmodels) (1.17.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in e:\data mining & analysis\.venv\lib\site-packages (from statsmodels) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in e:\data mining & analysis\.venv\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in e:\data mining & analysis\.venv\lib\site-packages (from statsmodels) (26.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\data mining & analysis\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pillow>=8 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\data mining & analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\data mining & analysis\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\data mining & analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Linear regression is a simple way to predict one thing using another by drawing a straight line through the data.
#
# * Predicts an output (dependent variable Y (Target Variable)) from an input (independent variable X)
# * Uses a straight line called the line of best fit
# * The intercept is where the line starts (At X = 0 what will be the Value of Y)
# * The slope/coeffiecent shows how much the output changes when the input increases how  much y increases when x incresed by 1 unit
# * Helps find relationships and make numerical predictions
# * Works well only if errors are random, independent, and consistent

# %%
import pandas as pd
#import pandas.util.testing as tm
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from statsmodels.compat import lzip
import statsmodels.formula.api as sm
import statsmodels.stats.stattools as st
import statsmodels.stats.api as sms
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('../data/raw/Adcampaign.csv')
df.head()
# Out:
#    Month  No. of Adverts (X)  No. of bookings (Y)
# 0      1                  20                   61
# 1      2                  24                   77
# 2      3                  30                   72
# 3      4                  23                   66
# 4      5                  27                   85

# %% [markdown]
# ### When you draw a scatter plot before linear regression, you are checking if the points roughly form a straight line.
#
# * Look for an upward or downward line pattern
# * It doesn’t need to be perfect, just a clear trend
# * Curved patterns can still work if you transform them
# * This helps you decide if linear regression is suitable for the data

# %%
sns.scatterplot(data = df, x = 'No. of Adverts (X)', y = 'No. of bookings (Y)')
plt.grid()

# %% [markdown]
# From the graph, even if the points don’t form a perfect line, a straight line can still reasonably represent the sales pattern because some error is always expected in real data.
#
# A perfect fit is not required — a rough linear trend is acceptable
#
# The error term accounts for the natural variation in data
#
# This error is expected to be random and normally distributed
#
# A straight line is therefore a practical and reasonable model here
#
# Reading Seltman’s simple linear regression chapter gives deeper understanding of this concept

# %%
sns.regplot(data = df, x = 'No. of Adverts (X)', y = 'No. of bookings (Y)', ci=95, scatter_kws={"color":"blue"}, line_kws={"color":"red"})
# Out:
# <Axes: xlabel='No. of Adverts (X)', ylabel='No. of bookings (Y)'>

# %% [markdown]
# In the regression plot, the shaded area around the line is the 95% confidence interval.
#
# It shows the range where the mean number of bookings is likely to fall for a given number of adverts
#
# It is not predicting the exact bookings, only the average expected bookings
#
# This interval is often inside the data points because it’s about the mean, not individual values
#
# In statistics, we assume the experiment could be repeated many times and this range shows where the average would fall
#
# Since the graph shows a reasonable linear trend, we can proceed with linear regression
#
# For now, we focus only on modeling bookings from adverts, not on train/test splits
#
# Next step is converting the pandas DataFrame into a NumPy array to use in the model

# %% [markdown]
# ***********************************************************************************
#
# Train/test split is used to check how well the model predicts unseen data
#
# Here, the aim is only to see whether adverts and bookings have a linear relationship
#
# We are exploring and understanding the pattern, not validating the model yet
#
# Splitting the data at this stage would distract from the main learning objective

# %%
x=df['No. of Adverts (X)'].to_numpy().reshape((-1, 1))
y=df['No. of bookings (Y)'].to_numpy().reshape((-1, 1))

# %% [markdown]
# After building the regression model, we use R² (coefficient of determination) to measure how well the line fits the data.
#
# R² ≈ 75% means adverts explain about 75% of the variation in bookings
#
# It’s only one indicator and can be misleading
#
# A high R² does not guarantee good predictions
#
# We also check the intercept (a) and slope (b) to understand the regression equation and how adverts affect bookings

# %%
model =LinearRegression().fit(x,y)

r_sq = model.score(x, y)
y_pred=model.predict(x)
df['error']=y-y_pred

print('coefficient of determination / square:', r_sq)
print('intercept:', model.intercept_)
print('coefficent:', model.coef_)
# Out:
# coefficient of determination / square: 0.7541051880057117
# intercept: [18.67045455]
# coefficent: [[2.21590909]]

# %%
df['error'] =  y - y_pred
print(df)

df.plot.scatter(x = 'No. of Adverts (X)', y = 'error')

df.plot.scatter(x='No. of bookings (Y)', y='error')
# Out:
#    Month  No. of Adverts (X)  No. of bookings (Y)      error
# 0      1                  20                   61  -1.988636
# 1      2                  24                   77   5.147727
# 2      3                  30                   72 -13.147727
# 3      4                  23                   66  -3.636364
# 4      5                  27                   85   6.500000
# 5      6                  25                   77   2.931818
# 6      7                  32                   90   0.420455
# 7      8                  35                  100   3.772727
# <Axes: xlabel='No. of bookings (Y)', ylabel='error'>

# %% [markdown]
# ### So this plot is checking:
#
# “Are the errors random?”
#
# * If yes → model is valid.
# * If no → model is wrong.

# %%
df4=df
df4=df4.rename(columns={"No. of bookings (Y)":"Y","No. of Adverts (X)":"X"})
formula_str="Y~X"  # y is dependent variable, X is independent variable Y dependent on X
print(df4)

results = sm.ols(formula=formula_str, data=df4).fit()
print(results.summary())

name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
test = sms.jarque_bera(results.resid)
print( lzip(name,test))
# Out:
#    Month   X    Y      error
# 0      1  20   61  -1.988636
# 1      2  24   77   5.147727
# 2      3  30   72 -13.147727
# 3      4  23   66  -3.636364
# 4      5  27   85   6.500000
# 5      6  25   77   2.931818
# 6      7  32   90   0.420455
# 7      8  35  100   3.772727
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     18.40
# Date:                Sun, 25 Jan 2026   Prob (F-statistic):            0.00515
# Time:                        18:31:08   Log-Likelihood:                -25.598
# No. Observations:                   8   AIC:                             55.20
# Df Residuals:                       6   BIC:                             55.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.6705     14.156      1.319      0.235     -15.969      53.310
# X              2.2159      0.517      4.290      0.005       0.952       3.480
# ==============================================================================
# Omnibus:                        5.111   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                1.643
# Skew:                          -1.099   Prob(JB):                        0.440
# Kurtosis:                       3.308   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [('Jarque-Bera', np.float64(1.6431802802120812)), ('Chi^2 two-tail prob.', np.float64(0.4397318629989245)), ('Skew', np.float64(-1.099392827143038)), ('Kurtosis', np.float64(3.308030010132124))]

# %% [markdown]
# * Dep. Variable: --> Target Variable
# * No. Observations: no of obv means total entries
# * Df Residuals: n - p - 1
#     Where n = No. Observations
#     p = no of features
#     1 = intersect
# * Df Model: Degree of Freedom (Number of Features )
# * Covariance Type: nonrobust (Equally Scatterd if not then robust)
# * R-squared: It Represents The Variablity how much % is explained by the model and Remaining Are noise (How well it fits the Model)
# * Adj. R-squared: It penalise noise and Increase if Feature is Useful

# %%
formula_str="Y~X"
print(df4)
result=sm.ols(formula=formula_str,data=df4).fit()
print(result.summary())


name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
test = sms.jarque_bera(result.resid)
print(name, test)
# Out:
#    Month   X    Y      error
# 0      1  20   61  -1.988636
# 1      2  24   77   5.147727
# 2      3  30   72 -13.147727
# 3      4  23   66  -3.636364
# 4      5  27   85   6.500000
# 5      6  25   77   2.931818
# 6      7  32   90   0.420455
# 7      8  35  100   3.772727
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     18.40
# Date:                Sun, 25 Jan 2026   Prob (F-statistic):            0.00515
# Time:                        18:36:17   Log-Likelihood:                -25.598
# No. Observations:                   8   AIC:                             55.20
# Df Residuals:                       6   BIC:                             55.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.6705     14.156      1.319      0.235     -15.969      53.310
# X              2.2159      0.517      4.290      0.005       0.952       3.480
# ==============================================================================
# Omnibus:                        5.111   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                1.643
# Skew:                          -1.099   Prob(JB):                        0.440
# Kurtosis:                       3.308   Cond. No.                         160.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis'] (np.float64(1.6431802802120812), np.float64(0.4397318629989245), np.float64(-1.099392827143038), np.float64(3.308030010132124))
